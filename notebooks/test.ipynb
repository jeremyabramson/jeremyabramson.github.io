# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/abramson/Desktop/cfb_data/2017/CSV/PBP - 2017 - Week 1.csv')

# %%
df[(df.homeTeam == 'Miami') & (df.isScoringPlay == True)]
# Out:
#          gameId  year  week  homeId homeTeam homeAbbr  awayId  \
# 7032  400937449  2017     1    2390    Miami    MIAMI    2065
# 7045  400937449  2017     1    2390    Miami    MIAMI    2065
# 7064  400937449  2017     1    2390    Miami    MIAMI    2065
# 7078  400937449  2017     1    2390    Miami    MIAMI    2065
# 7087  400937449  2017     1    2390    Miami    MIAMI    2065
# 7105  400937449  2017     1    2390    Miami    MIAMI    2065
# 7122  400937449  2017     1    2390    Miami    MIAMI    2065
# 7136  400937449  2017     1    2390    Miami    MIAMI    2065
# 7155  400937449  2017     1    2390    Miami    MIAMI    2065
# 7187  400937449  2017     1    2390    Miami    MIAMI    2065
#
#              awayTeam awayAbbr  driveIndex  ...  isScoringPlay  quarter  \
# 7032  Bethune-Cookman      BCU           0  ...           True        1
# 7045  Bethune-Cookman      BCU           1  ...           True        1
# 7064  Bethune-Cookman      BCU           3  ...           True        2
# 7078  Bethune-Cookman      BCU           5  ...           True        2
# 7087  Bethune-Cookman      BCU           7  ...           True        2
# 7105  Bethune-Cookman      BCU           8  ...           True        2
# 7122  Bethune-Cookman      BCU          10  ...           True        3
# 7136  Bethune-Cookman      BCU          11  ...           True        3
# 7155  Bethune-Cookman      BCU          14  ...           True        3
# 7187  Bethune-Cookman      BCU          18  ...           True        4
#
#       clock               type  down distance yardLine  yardsGained  \
# 7032   7:25    Field Goal Good     4       16       19           36
# 7045   3:19    Field Goal Good     4        0       90           27
# 7064  13:31  Rushing Touchdown     1        0       95            5
# 7078   8:31  Passing Touchdown     3        0       95            5
# 7087   5:34  Passing Touchdown     2        4       95            5
# 7105   0:53    Field Goal Good     4        0       18           35
# 7122  12:30  Rushing Touchdown     1        0       94            6
# 7136   6:16  Rushing Touchdown     2        0        1            1
# 7155   1:08  Passing Touchdown     1       10       78           22
# 7187   5:14    Field Goal Good     4       23       67           50
#
#       endYardLine                                        description
# 7032           19                      Uriel Hernandez 36 yd FG GOOD
# 7045           90                      Michael Badgley 27 yd FG GOOD
# 7064          100  Mark Walton run for 5 yds for a TD, (Michael B...
# 7078          100  Malik Rosier pass complete to Lawrence Cager f...
# 7087          100  Malik Rosier pass complete to Darrell Langham ...
# 7105           18                      Uriel Hernandez 35 yd FG GOOD
# 7122          100  Mark Walton run for 6 yds for a TD, (Michael B...
# 7136            0  Michael Jones run for 1 yd for a TD, (Uriel He...
# 7155          100  Malik Rosier pass complete to Braxton Berrios ...
# 7187           80                      Michael Badgley 50 yd FG GOOD
#
# [10 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['gameId', 'year', 'week', 'homeId', 'homeTeam', 'homeAbbr', 'awayId',
#        'awayTeam', 'awayAbbr', 'driveIndex', 'playIndex', 'offenseId',
#        'offenseTeam', 'offenseAbbr', 'defenseId', 'defenseTeam', 'defenseAbbr',
#        'homeScore', 'awayScore', 'isScoringPlay', 'quarter', 'clock', 'type',
#        'down', 'distance', 'yardLine', 'yardsGained', 'endYardLine',
#        'description'],
#       dtype='object')
